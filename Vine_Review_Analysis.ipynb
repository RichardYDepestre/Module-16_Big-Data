# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardYDepestre/amazon_vine_analysis/blob/main/Vine_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# Find the latest version of spark 2.0  from http://www-us.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.0'
spark_version = 'spark-3.0.2'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www-us.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:5 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:14 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,770 kB]
# Get:15 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [906 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [480 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [33.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,616 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,184 kB]
# Get:20 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [40.9 kB]
# Get:23 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [450 kB]
# Get:24 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,184 kB]
# Get:25 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,414 kB]
# Fetched 12.4 MB in 3s (3,867 kB/s)
# Reading package lists... Done

# %%
# Download the Postgres driver that will allow Spark to interact with Postgres.
# !wget https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Out:
# --2021-06-06 21:34:56--  https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Resolving jdbc.postgresql.org (jdbc.postgresql.org)... 72.32.157.228, 2001:4800:3e1:1::228
# Connecting to jdbc.postgresql.org (jdbc.postgresql.org)|72.32.157.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1002883 (979K) [application/java-archive]
# Saving to: ‘postgresql-42.2.16.jar’
#
# postgresql-42.2.16. 100%[===================>] 979.38K  1.68MB/s    in 0.6s
#
# 2021-06-06 21:34:58 (1.68 MB/s) - ‘postgresql-42.2.16.jar’ saved [1002883/1002883]

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("BigData-Challenge").config("spark.driver.extraClassPath","/content/postgresql-42.2.16.jar").getOrCreate()

# %% [markdown]
# ### Load Amazon Data into Spark DataFrame

# %%
from pyspark import SparkFiles
url = "https://s3.amazonaws.com/amazon-reviews-pds/tsv/amazon_reviews_us_Home_v1_00.tsv.gz"
spark.sparkContext.addFile(url)
# df = spark.read.option("encoding", "UTF-8").csv(SparkFiles.get("amazon_reviews_us_Home_v1_00.tsv.gz"), sep="\t", header=True, inferSchema=True)
# df.show(truncate=False)

# %% [markdown]
# ### Create DataFrames to match tables

# %%
from pyspark.sql.functions import to_date
# Read in the Review dataset as a DataFrame
df = spark.read.option("encoding", "UTF-8").csv(SparkFiles.get("amazon_reviews_us_Home_v1_00.tsv.gz"), sep="\t", header=True, inferSchema=True)
df.show(5, truncate=False)

# %%
print(f"entries in dataset: {df.count()}")
# Out:
# entries in dataset: 6221559

# %%
# Filter the data and create a new DataFrame or table to retrieve all the rows where 
# the total_votes count is equal to or greater than 20 to pick reviews that are more likely to 
# be helpful and to avoid having division by zero errors later on.
n_df_gt20 = df.filter(df.total_votes >= 20)
n_df_gt20.show(5, truncate=False)
# Out:
# +-----------+-----------+--------------+----------+--------------+----------------------------------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+
# |marketplace|customer_id|review_id     |product_id|product_parent|product_title                                                                                             |product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|review_headline                                                              |review_body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |review_date|
# +-----------+-----------+--------------+----------+--------------+----------------------------------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+
# |US         |32555853   |R27XX9MG7OWSSM|B00CMV99HU|475264259     |5 x 20 Quality Canvas 9 Oz. Drop Cloth Runner                                                             |Home            |5          |49           |51         |N   |Y                |Made Curtains out of them and they worked well                               |I bought these for curtain panels and was able to make 2 panels out of each( 9 ft celings). They do shrink a bit but you have to factor that<br />in if you want to use it for curtains etc..So far it is working out and suits our purpose..economical drapes that are longer than your standard 84 incht! So, my 5 star rating is for its function as a curtain and not a true painter's dropcloth!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |2015-08-31 |
# |US         |24278614   |R1I4IFDOW6IW9O|B00ZAUWZ6M|195636450     |Ellington Home 1800 Series 3 Piece Damask Stripe Duvet Cover Set                                          |Home            |3          |44           |47         |N   |Y                |Thin, slightly plastic-y look to it, cheap material.                         |Ordered this for a potential duvet for my room.  I liked the color when it arrived, but the thinness of the material and the odd plastic-y sheen to the fabric turned me off. The material is very thin, and feels very insubstantial.  There is an odd sheen to the material, almost like it is woven with a substandard thread. It gives off the impression that the material is very cheap. The color was very nice, but not as bright or as saturated as the photo on amazon. I tried to get a good photo of the color but it is hard to catch accurately.  If this was of a thicker material and made from a higher quality fabric, it would have been perfect.  As it is not, this is going back.   Also the reviews for this set on Amazon are all extremely effusive and they almost all seem to give it 4 and 5 star reviews.  I was swayed by the reviews, but IMO, these were people who were essentially &#34;paid&#34; with a free/heavily discounted product to provide good feedback, and still have the &#34;Amazon verified purchase&#34; on the feedback.  Not many people are going to knock a free or heavily discounted product, especially if they have no intention of actual using it for the intended purchase ever again.    Considering I am spending my own money and have a real purpose for this set, ie: Daily Use in my bedroom, I expected it to meet or exceed certain expectations regarding quality, materials, looks, color, etc.  This was just such a let-down.    There are better quality duvets on amazon for a similar price...I am going with a different brand instead of this one, and I recommend that anyone looking at this duvet cover set look elsewhere to. Save your money and get something of decent quality.|2015-08-31 |
# |US         |35722247   |R2LZAV3VMLGPGS|B00LLI8RGO|16515808      |All for You 3pc Reversible Quilt Set, Bedspread, and Coverlet-burgundy color                              |Home            |3          |32           |33         |N   |Y                |Nice design but WAY TOO SMALL!!!                                             |I ordered the King Size with 2 king shams and I am a little disappointed in the size. It is more of a perfect fit for a Full/Queen size bed to get complete coverage. On my king bed it does not even cover the Mattress completely at the foot of the bed it has about 2-3 inches exposed of the mattress and the sides also barely begins to cover  it. The design and color is nice but if you want this for a king size bed. I don't recommend it I would use this King Size on a QUEEN or FULL size bed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |2015-08-31 |
# |US         |40740421   |R3FITR2BQI94RA|B00NCL0MAC|361959449     |Deluxe Chrome-plated Steel 2-Tier Dish Rack with Drainboard / Cutlery Cup                                 |Home            |5          |33           |38         |N   |Y                |Perfect for Limited Counter Space; Assembly Is Unpleasant but Can Be Forgiven|I live in an apartment, so I have one of those kitchens where the counter space makes your eager inner check weep into his/her hat and sadly hang up the apron.  I needed a dish rack that wouldn't use up too much needed space.  I prefer to have it out on the counter always so that I can rinse some dishes immediately after use and thus cut down on washing.  This double-decker design is perfect for saving the counter space, the tray holds plenty of drips without flooding the counter (also important), and the design is flexible enough to accommodate pretty much any type of dish I have.  It's nice and sturdy, so no worries about it breaking any treasured glassware.  What I particularly like about this model is that it has those extra details that make it aesthetically pleasing -- there's just something happy about having an attractive kitchen, even if it is tiny.  Oddly enough, I've had multiple friends even comment on how attractive this dish drainer is!  You don't normal get that.<br /><br />One thing to be aware of, however (I almost considered deducting a star, but the truth is that I'm so happy with the product that I decided to forgive this flaw):  This is no picnic to assemble!  It is a PAIN to put together at first.  My dog almost heard some very naughty words coming out of my mouth as I battled this together.  However, after about 20-30 minutes, I figured it out and since I keep it out on the counter always, I have never had to repeat that shameful performance.                                                                                                                                                                                                                   |2015-08-31 |
# |US         |39387962   |RWYBT1R3KPD2M |B00W2KG92Y|150649056     |Frigidaire FFRA0511R1 5, 000 BTU 115V Window-Mounted Mini-Compact Air Conditioner with Mechanical Controls|Home            |4          |142          |163        |N   |Y                |Great Value                                                                  |I'm running it in the middle of nowhere really - the side of volcano with photovoltaic power, and when needed, a Honda i2000 generator. I'm rather amazed at this air conditioner. Right now it's running at full power high cool and the generator hardly made a growl - it is indeed running at about 4.5 amps (the i2000 is a 20 amp generator). I'm about 4 feet from it, and it's AMAZINGLY quiet. It's outrageously hot and humid here, so I don't expect the room to get frigid, but after running it for one hour, the room is very comfortable.<br /><br />Let's see how long it lasts!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |2015-08-31 |
# +-----------+-----------+--------------+----------+--------------+----------------------------------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+
# only showing top 5 rows

# %%
print(f"all rows total votes count greater or equal to 20: {n_df_gt20.count()}")
n_df_gt20.columns
# Out:
# all rows total votes count greater or equal to 20: 96370
# ['marketplace',
#  'customer_id',
#  'review_id',
#  'product_id',
#  'product_parent',
#  'product_title',
#  'product_category',
#  'star_rating',
#  'helpful_votes',
#  'total_votes',
#  'vine',
#  'verified_purchase',
#  'review_headline',
#  'review_body',
#  'review_date']

# %%
# Filter the new DataFrame or table created in Step 1 and create a new DataFrame or 
# table to retrieve all the rows where the number of helpful_votes divided by total_votes 
# is equal to or greater than 50%.
# If you use the SQL option below, you’ll need to cast your columns as floats using 
# WHERE CAST(helpful_votes AS FLOAT)/CAST(total_votes AS FLOAT) >=0.5.
hlp_votes = n_df_gt20.helpful_votes
ttl_votes =  n_df_gt20.total_votes
pct = 0.5
n_df_votes = n_df_gt20.filter((hlp_votes/ttl_votes)>=pct)
print(f"number of votes: {n_df_votes.count()}.")
n_df_votes.show()

# %%
# Filter the DataFrame or table created in Step 2, and create a new DataFrame or table that retrieves 
# all the rows where a review was written as part of the Vine program (paid), vine == 'Y'.
rows_w_reviews = n_df_votes.filter(n_df_votes.vine == "Y")
rows_w_reviews.show(5, truncate=False)
print(f"number of rows with reviews: {rows_w_reviews.count()}.")
# Out:
# +-----------+-----------+--------------+----------+--------------+---------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+---------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |marketplace|customer_id|review_id     |product_id|product_parent|product_title                                                                    |product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|review_headline                                                      |review_body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# +-----------+-----------+--------------+----------+--------------+---------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+---------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |US         |52815715   |R2W1OMYJERBXJ1|B00SFUVNKS|977603375     |Panasonic MC-CL943 JETFORCE Mult-Surface Bagless Canister Vacuum Cleaner - Corded|Home            |5          |20           |23         |Y   |N                |Compact and powerful                                                 |With pets in the house a good vacuum is a necessity. The Panasonic Jetforce is as capable as it is compact. While I used to love my Dyson, the Panasonic has the same (and better) features, plus it edges it out in several ways.<br /><br />It’s short and small, it rolls easily and for a vacuum, it’s on the quieter side. It’s really easy to maneuver around the house, up and down 3 floors. It’s lightweight and has a handle that makes it easy to carry. The power cord is retractable! So much nicer than the wrapping around posts.The HEPA filtered bagless system is easy to empty, but one trade off is that it doesn’t hold a lot, so you might find yourself emptying this a few times in the course of a full day of cleaning. Also, the dust cup is fully washable as well. This is a feature I like as vacuums can accumulate a musty odor from the collected dirt and dust.  Washing the dust cup out goes a long way in preventing that.<br /><br />The Jetforce has a crevice tool and a dusting brush that snap on to the telescoping wand and are stored on the wand just below the handle. You can switch from carpet to hard wood with the push of a button on the wand. The Gliding Pet Brush works very well in picking up pet fur from the carpet and the sofa. It has two rollers and they do a noticeably better job at collecting pet hair than I am used to.<br /><br />Overall, this is a compact vacuum that has a lot of features and is well designed. The compact design is great not only for when you’re using it, but it takes up little storage space as well. It’s a pleasure to use, it does a great job with carpets, tile, hardwood and furniture. It’s a lot less than what I paid for my Dyson and I’d say this is easily my favorite vacuum.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |US         |13663596   |R31VJCBBKU13Y |B0105TXVRE|820889787     |Electrolux EL4335A Corded Ultra Flex Canister Vacuum                             |Home            |5          |24           |27         |Y   |N                |It actually does what it says....it CLEANS. What a refreshing change.|I consider myself something of a vacuum expert. With two children (three, if count my husband which I frequently do) who seem to suffer from memory loss when it comes to TAKE OFF YOUR SHOES INSIDE!!!, I live with a never ending barrage of dirt, pine needles, and heaven knows what other awful outside stuff being tracked inside constantly. Every day. You can only fight it with a vacuum. So as you can probably imagine, I've been through countless vacuums. And I'm here to tell you, most all of them are meh at best. Most of the vacuums I've gone through have been mid-price ranged Dirt Devils and the like, although I do have one 5 year old Dyson here that was supposed to be the be-all-end-all of vacuums that turned out to be no better than the Dirt Devils (and a pain in the heinie to clean the canister, to boot, so it doesn't get used much at all).<br /><br />Enter Electrolux. I've had it for 15 days now so I can only give a preliminary report, but holy moly guacamole: THIS is a vacuum. I went into this with a fair amount of skepticism....oh sure, put a fancy brand name on it and charge 5x as much....but in this case, you get what you pay for. This vacuum cleans like you would not believe. So did we get that part out of the way? It cleans like crazy....wow.<br /><br />Okay, so it has features. Normally, I couldn't care less about extra features because I don't tend to use many of them. But Electrolux had someone just like me designing this darned thing. First of all....a handy switch *on the handle* to switch from hardwoods to carpet. Thank you. Couldn't be easier or make more sense. Next, the attachments (slim nozzle for getting into places like your sliding glass door casement where it gets so yukky and the duster for your baseboards) are in the darned handle. Takes two seconds to switch to them. And the suction on the Electrolux is so good that the attachments WORK. (Did I mention that this vacuum works?) There are two other attachments that come with the vacuum that don't store on it - another hardwood floor attachment which is optional and an upholstery one - although because they aren't stored on the vacuum I probably will lose them, ha.<br /><br />Now for one of my biggest litmus tests: cleaning it out. The canister couldn't be easier to clean. Quick and easy to dump in the garbage can plus you can see from the outside of the vacuum when it's getting full and needs to be emptied.<br /><br />Add to all of this how quiet this thing is (especially on hardwood floor setting) and you'll love it so much. I'll update the review to let you know how it's holding up over time because that is the failing of most vacuums in my opinion, but this thing is amazing. And worth it.on't store on it - another hardwood floor attachment which is optional and an upholstery one - although because they aren't stored on the vacuum I probably will lose them, ha.<br /><br />Now for one of my biggest litmus tests: cleaning it out. The canister couldn't be easier to clean. Quick and easy to dump in the garbage can plus you can see from the outside of the vacuum when it's getting full and needs to be emptied.<br /><br />Add to all of this how quiet this thing is (especially on hardwood floor setting) and you'll love it so much. I'll update the review to let you know how it's holding up over time because that is the failing of most vacuums in my opinion, but this thing is amazing. And worth it.                                                                                                                                                                                                                                                                                       ...
# |US         |28113646   |R350JNDV0INC11|B0105TXVRE|820889787     |Electrolux EL4335A Corded Ultra Flex Canister Vacuum                             |Home            |4          |388          |398        |Y   |Y                |Head to Head Competition - Electrolux, ProTeam, Sanyo Vs. Our Cats   |We have a relatively large home, and two decidedly large and furry cats. These combine to create vacuuming challenges which we've used various tools to combat over the past ten years. Until recently, the winner has always been our old trusty Sanyo upright. Pushing the 20-year mark, it still seemed to suck with the best of them, and do a decent job at cat hair removal. About 6 months ago we got a ProTeam vacuum (ProTeam ProForce 1500XP HEPA Upright) for the lower floors of the house, and the Sanyo moved upstairs, now this Electrolux comes into the house ready for a fight to see who comes out on top in the suction wars.<br /><br />To keep the fight fair, I first marked stripes in the middle of our most used pathway through the exercise/game room, creating three lanes of the same width and length (Photo #1). This area sees more grime and cat hair than any other in the house, and it hadn't been vacuumed in 4 or 5 days, so it should be a very good test area. I also sprinkled baking soda in a line across all three lanes to give us a visual for any issues caused by ineffective suction or brushes (Photo #2).<br /><br />The ProTeam and Sanyo received new, clean bags and their filters and brushes were cleaned like I do every time I replace a bag.<br /><br />Each vacuum ran slowly forward then backward one time along their lane (photo #3), then the bags (and canister) were removed and the contents dumped in the separate piles you see in photo #4.<br /><br />The results were exactly what I expected, the Sanyo came out the loser in this competition and is now relegated to the shop to wheeze out its final days. The other two were more evenly matched, with the ProTeam upright pulling up all the granular material but not as much cat hair and carpet fiber, and the Electrolux winning gold with the largest hairball and just slightly less granular material.<br /><br />We’ll be like Jeopardy here and kick the Sanyo to the curb and compare the two top performers in a few categories.<br /><br />Ease of Use:<br /><br />+ The ProTeam is simple, plug it in, turn it on, go. It has basic attachments and is simple for anyone to use. Pretty much anyone familiar with a vacuum could easily operate this one with no instructions or prior knowledge.<br />- The Electrolux is a more complex beast, although most people could quickly figure it out and be vacuuming in a few minutes, the attachments and extra bells and whistles make for a steeper learning curve if you want to take full advantage of its assets.<br /><br />Speed in cleaning:<br />+/- The ProTeam cuts a wider swath and for the average healthy adult will be a faster way to vacuum a one-story home. The downside is that it can get fatiguing for people with less upper body strength, especially if you’re working with a big area.<br />+/- The Electrolux takes me about 3 or 4 more minutes to finish our large living room because of the smaller head and moving the canister around behind me. On the plus side, it takes much less effort to navigate it through the jungle of chair legs and nooks and crannies. If you add stairs to the mix, the Electrolux wins hands down.<br /><br />Ease of emptying and filter replacement:<br />+ The ProTeam bag replacement is simple and straightforward, as is filter cleaning and replacement. The bag comes out the top and the new one goes back in place easily. The motor intake filter is washable and re-usable. The HEPA filters require replacement, they cost $10 each and there are two of them (the company recommends replacement with every other new bag, but visual inspection after 3 bags shows no discoloration or debris).<br />-  The Electrolux doesn’t require bags and you can empty it more often ...
# |US         |33244285   |R2NJA2I5C9Y0FR|B010FQ4STC|256488195     |Dyson V6 Mattress Handheld Vacuum - Cordless                                     |Home            |3          |63           |73         |Y   |N                |Mixed Feelings                                                       |I really have mixed feelings about this appliance. It is obvious from the heading on my review that I received this for free. So, when I considered how to review it, I couldn't help but ask myself the question, &#34;Would I pay the price for this product?&#34;<br /><br />On the one hand, it's worth the money.<br />- It attracts the fine dust that holds dust mites, seeming pulling it up from deep within a mattress.<br />- The suction is quite powerful, making this useful on mattresses, upholstery, and even some carpeting (I would recommend being careful with carpet cleanings - make sure to vacuum first and be attentive to the type of carpet being vacuumed).<br />- Frequently battery-powered suction is not as strong as suction from a corded appliance. But, in this case, Dyson has presented a well-made cordless product.<br /><br />So, why only rate it three stars? Well, there are several reasons.<br />1) There is a price to pay for strong suction in a cordless product - the power is not very long-lasting. This is fine if you only have, say, a single queen/king mattress or a couch and a couple of chairs to deal with. But, in a family situation where, in all honesty, every mattress needs to be tackled, this product takes three or four charges, at least.  At three hours per charge, that's not very accommodating to &#34;sheet-changing day&#34; or other scheduling that works best for a family. I would have preferred the cordless function to be optional, with a corded option available for high-demand jobs.<br />2) The instructions say nothing about mattresses. Period. This is labeled a mattress vacuum, yet all of the instruction refer to carpet and upholstery. Although the actual process is self-explanatory (vacuum the mattress!), it would be helpful to know what the different speeds are more useful for, how important it is to utilize the high speed every time, how to know if you have really cleaned the mattress well, how quickly or slowly to process over the mattress, etc.Make the instructions applicable to the appliance.<br />3) Finally, if you're going to pay such a price for a small appliance like this, some kind of storage bag would be a nice addition.<br /><br />Bottom Line: I know that this is an appliance useful for much more than just mattresses. But, it also has its limits. Were this to be a corded product, I'd probably pay the price for it because of its versatility. But, the battery limitations are a pretty big issue for me. I'm glad to have it, but because we do need to contemplate what &#34;extra&#34; items do and do not fit the budget, I can't say that this one would automatically make the cut.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# |US         |37840725   |R296RSG25RD1IX|B011LS47SA|107908024     |Bissell 1544A PowerFresh Lift-Off Pet Steam Mop - PARENT                         |Home            |3          |46           |51         |Y   |N                |Disappointed                                                         |I was thrilled by the performance and multi functional cleaning uses of this Bissell steamer at first but after a month of constant use, the detachable function no longer works.  I was looking forward to receiving this steam mop/cleaner and opened it as soon as it arrived.  I may have even grabbed it out of the mailman's hands I was so excited to try it. I have 2 dogs, 2 cats and 2 boys that all seem intent on making the house as messy as possible.  It's a never ending battle.  It was easy to assemble, fill with water and use (I added a few drops of fresh lemon juice to the water, I have no idea if this is a good idea on certain flooring).  It left my floors clean and with a fresher scent.  The water container lasts for a more than a medium sized room.  I really needed this for the attachment steamer that easily disconnects from the mop to steam clean certain chairs and sofas that I see pets slinking off of in the morning.  I currently use Febreeze(TM) but figured this was a better way to actually remove pet smells instead of masking it.  There isn't an attachment made for upholstery cleaning  but we used one of the small ones and it worked like a charm on the sofa and chairs for the first month.  I also used it to clean around my kitchen and it did an amazing job at getting rid of the gunk between my counter and undermount sink but I doubt I'd use it every time I clean.  Unfortunately, the handheld steamer would no longer operate once detached from the mop (stuck on ready button) and as strictly a mop, it works but the draw was the multiple uses of one device.<br /><br />UPDATE:  After hearing from Bissell, I contacted customer support (1-800-237-7691) and did not have the best results.  Bottom line, I probably caused the issue by adding fresh lemon juice and even though it's not a chemical and I've used it with other steam mops and cleaners, it was the likely culprit.  I am still disappointed by customer service whose english was limited and did not provide help.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# +-----------+-----------+--------------+----------+--------------+---------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+---------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows
#
# number of rows with reviews: 1448.

# %%
# Filter the DataFrame or table created in Step 2, and create a new DataFrame or table that retrieves 
# all the rows where a review was written as part of the Vine program (paid), vine == 'N'.
rows_wo_reviews = n_df_votes.filter(n_df_votes.vine == "N")
rows_wo_reviews.show(5, truncate=False)
print(f"number of rows without reviews: {rows_wo_reviews.count()}.")
# Out:
# +-----------+-----------+--------------+----------+--------------+----------------------------------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+
# |marketplace|customer_id|review_id     |product_id|product_parent|product_title                                                                                             |product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|review_headline                                                              |review_body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |review_date|
# +-----------+-----------+--------------+----------+--------------+----------------------------------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+
# |US         |32555853   |R27XX9MG7OWSSM|B00CMV99HU|475264259     |5 x 20 Quality Canvas 9 Oz. Drop Cloth Runner                                                             |Home            |5          |49           |51         |N   |Y                |Made Curtains out of them and they worked well                               |I bought these for curtain panels and was able to make 2 panels out of each( 9 ft celings). They do shrink a bit but you have to factor that<br />in if you want to use it for curtains etc..So far it is working out and suits our purpose..economical drapes that are longer than your standard 84 incht! So, my 5 star rating is for its function as a curtain and not a true painter's dropcloth!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |2015-08-31 |
# |US         |24278614   |R1I4IFDOW6IW9O|B00ZAUWZ6M|195636450     |Ellington Home 1800 Series 3 Piece Damask Stripe Duvet Cover Set                                          |Home            |3          |44           |47         |N   |Y                |Thin, slightly plastic-y look to it, cheap material.                         |Ordered this for a potential duvet for my room.  I liked the color when it arrived, but the thinness of the material and the odd plastic-y sheen to the fabric turned me off. The material is very thin, and feels very insubstantial.  There is an odd sheen to the material, almost like it is woven with a substandard thread. It gives off the impression that the material is very cheap. The color was very nice, but not as bright or as saturated as the photo on amazon. I tried to get a good photo of the color but it is hard to catch accurately.  If this was of a thicker material and made from a higher quality fabric, it would have been perfect.  As it is not, this is going back.   Also the reviews for this set on Amazon are all extremely effusive and they almost all seem to give it 4 and 5 star reviews.  I was swayed by the reviews, but IMO, these were people who were essentially &#34;paid&#34; with a free/heavily discounted product to provide good feedback, and still have the &#34;Amazon verified purchase&#34; on the feedback.  Not many people are going to knock a free or heavily discounted product, especially if they have no intention of actual using it for the intended purchase ever again.    Considering I am spending my own money and have a real purpose for this set, ie: Daily Use in my bedroom, I expected it to meet or exceed certain expectations regarding quality, materials, looks, color, etc.  This was just such a let-down.    There are better quality duvets on amazon for a similar price...I am going with a different brand instead of this one, and I recommend that anyone looking at this duvet cover set look elsewhere to. Save your money and get something of decent quality.|2015-08-31 |
# |US         |35722247   |R2LZAV3VMLGPGS|B00LLI8RGO|16515808      |All for You 3pc Reversible Quilt Set, Bedspread, and Coverlet-burgundy color                              |Home            |3          |32           |33         |N   |Y                |Nice design but WAY TOO SMALL!!!                                             |I ordered the King Size with 2 king shams and I am a little disappointed in the size. It is more of a perfect fit for a Full/Queen size bed to get complete coverage. On my king bed it does not even cover the Mattress completely at the foot of the bed it has about 2-3 inches exposed of the mattress and the sides also barely begins to cover  it. The design and color is nice but if you want this for a king size bed. I don't recommend it I would use this King Size on a QUEEN or FULL size bed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |2015-08-31 |
# |US         |40740421   |R3FITR2BQI94RA|B00NCL0MAC|361959449     |Deluxe Chrome-plated Steel 2-Tier Dish Rack with Drainboard / Cutlery Cup                                 |Home            |5          |33           |38         |N   |Y                |Perfect for Limited Counter Space; Assembly Is Unpleasant but Can Be Forgiven|I live in an apartment, so I have one of those kitchens where the counter space makes your eager inner check weep into his/her hat and sadly hang up the apron.  I needed a dish rack that wouldn't use up too much needed space.  I prefer to have it out on the counter always so that I can rinse some dishes immediately after use and thus cut down on washing.  This double-decker design is perfect for saving the counter space, the tray holds plenty of drips without flooding the counter (also important), and the design is flexible enough to accommodate pretty much any type of dish I have.  It's nice and sturdy, so no worries about it breaking any treasured glassware.  What I particularly like about this model is that it has those extra details that make it aesthetically pleasing -- there's just something happy about having an attractive kitchen, even if it is tiny.  Oddly enough, I've had multiple friends even comment on how attractive this dish drainer is!  You don't normal get that.<br /><br />One thing to be aware of, however (I almost considered deducting a star, but the truth is that I'm so happy with the product that I decided to forgive this flaw):  This is no picnic to assemble!  It is a PAIN to put together at first.  My dog almost heard some very naughty words coming out of my mouth as I battled this together.  However, after about 20-30 minutes, I figured it out and since I keep it out on the counter always, I have never had to repeat that shameful performance.                                                                                                                                                                                                                   |2015-08-31 |
# |US         |39387962   |RWYBT1R3KPD2M |B00W2KG92Y|150649056     |Frigidaire FFRA0511R1 5, 000 BTU 115V Window-Mounted Mini-Compact Air Conditioner with Mechanical Controls|Home            |4          |142          |163        |N   |Y                |Great Value                                                                  |I'm running it in the middle of nowhere really - the side of volcano with photovoltaic power, and when needed, a Honda i2000 generator. I'm rather amazed at this air conditioner. Right now it's running at full power high cool and the generator hardly made a growl - it is indeed running at about 4.5 amps (the i2000 is a 20 amp generator). I'm about 4 feet from it, and it's AMAZINGLY quiet. It's outrageously hot and humid here, so I don't expect the room to get frigid, but after running it for one hour, the room is very comfortable.<br /><br />Let's see how long it lasts!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |2015-08-31 |
# +-----------+-----------+--------------+----------+--------------+----------------------------------------------------------------------------------------------------------+----------------+-----------+-------------+-----------+----+-----------------+-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+
# only showing top 5 rows
#
# number of rows with out reviews: 90768.

# %%
# Determine the total number of reviews
total_reviews = rows_w_reviews.count()
print(f"total purchases with reviews {total_reviews}.")
total_no_reviews = rows_wo_reviews.count()
print(f"total purchases without reviews {total_no_reviews}.")

# the number of 5-star reviews
five_star_reviews = rows_w_reviews.filter(rows_w_reviews.star_rating == 5).count()
print(f"\npurchases with 5-star review: {str(five_star_reviews)}.")
five_star_no_reviews = rows_wo_reviews.filter(rows_wo_reviews.star_rating == 5).count()
print(f"purchases without 5-star review: {str(five_star_no_reviews)}.")

five_star_reviews_pct = (five_star_reviews / total_reviews) * 100
print(f"\npercent purchases with 5-star review: {str(five_star_reviews_pct)}.")
five_star_no_reviews_pct = (five_star_no_reviews / total_no_reviews) * 100
print(f"\percent purchases with 5-star no review: {str(five_star_no_reviews_pct)}.")
# Out:
# total purchases with reviews 1448.
# total purchases without reviews 90768.
#
# purchases with 5-star review: 647.
# purchases without 5-star review: 44104.
#
# percent purchases with 5-star review: 44.68232044198895.
# \percent purchases with 5-star no review: 48.589811387273045.
